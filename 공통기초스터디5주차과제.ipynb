# %% [markdown]
# <a href="https://colab.research.google.com/github/1oneweeek/DALC_Scala/blob/main/%EA%B3%B5%ED%86%B5%EA%B8%B0%EC%B4%88%EC%8A%A4%ED%84%B0%EB%94%945%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')
plt.savefig('my_figure.jpg')

# %%
from google.colab import files
files.download('my_figure.jpg')

# %%
#1. 선그림
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig = plt.figure()
fig.suptitle("Example 1:Line Plot")
ax = plt.axes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-030308bd4810> in <module>()
#       6 fig = plt.figure()
#       7 fig.suptitle("Example 1:Line Plot")
# ----> 8 plt.plot(x, y);
#       9 ax = plt.axes
#
# NameError: name 'x' is not defined

# %%
#3. 점그림
x = np.linspace(0, 15, 25)
plt.plot(x, x, 'o', color='r')
plt.plot(x, x+2, '.', color='g')
plt.plot(x, x+4, 's-', color='b')
plt.plot(x, x+6, 'd--', color='c');

# %%
plt.plot(x, np.sin(x), '-og');

# %%
mg = np.random.RandomState(seed=0)
data = mg.randn(50, 2)
x, y = data[:,0], data[:,1] colors = mg.rand(50)
sizes = 1000*mg.rand(50)plt.subplot(2, 1, 1)
plt.scateer(x, y, c = colors, s = sizes, alpha=0.4,
            cmap = 'plasma')
plt.colorbar()
plt.subplot(2, 1, 2)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.4,
            cmap='viridis')
plt.colorbar
# Out:
#   File "<ipython-input-18-7ff4a84d0880>", line 3
#     x, y = data[:,0], data[:,1] colors = mg.rand(50)
#                                      ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

nrows, ncols = 3, 4
for i in range(nrows*ncols):
  plt.subplot(nrows, ncols, i+1)
  plt.text(0.5, 0.5, str((nrows, ncols, i+1)), fontsize=16, ha='center')

# %%
nrows, ncols = 3, 4
grid = plt.GridSpec(nro, 4, wspace=0.4, hspace=0.4)
ax1 = plt.subplot(grid[0,0])
ax2 = plt.subplot(grid[0,1:3])
ax3 = plt.subplot(grid[1:, :2])
ax4 = plt.subplot(grid[1:,2])
ax5 = plt.subplot(grid[:, 3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-34c42373c330> in <module>()
#       1 nrows, ncols = 3, 4
# ----> 2 grid = plt.GridSpec(nro, 4, wspace=0.4, hspace=0.4)
#       3 ax1 = plt.subplot(grid[0,0])
#       4 ax2 = plt.subplot(grid[0,1:3])
#       5 ax3 = plt.subplot(grid[1:, :2])
#
# NameError: name 'nro' is not defined
